# %% [markdown]
# # Summary of Notebook
# - clustering really wasn't helpful. No insights were gained.
# - maybe zooplankton has no effect on length of fish

# %% [markdown]
# # Importing libraries and dataframe

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans # Here is where you import the k-means algorithm from scikit-learn.
import pylab as pl # PyLab is a convenience module that bulk imports matplotlib.

# %%
# This option ensures the graphs you create are displayed in your notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
path =  r'C:\Users\Selena\Desktop\6-17-22 Michigan Anglers'
df_anglers = pd.read_csv(os.path.join(path, '02 Data', 'Prepared', 'chinook_coho_lake_cleaned_categories_anglers_size_stocking_plankton_combined.csv'), index_col=False)

# %% [markdown]
# # Checking and cleaning imported dataframe

# %%
df_anglers.head()
# Out:
#    Unnamed: 0        category         species      waterbody lake     merge  \
# 0           0  Catch and Keep  chinook salmon     Lake Huron   HU  lk_huron
# 1           1  Catch and Keep      lake trout  Lake Superior   SU    lk_sup
# 2           2  Catch and Keep      lake trout  Lake Superior   SU    lk_sup
# 3           3  Catch and Keep      lake trout  Lake Superior   SU    lk_sup
# 4           4  Catch and Keep      lake trout  Lake Superior   SU    lk_sup
#
#               datetime date caught time caught  year  ...  \
# 0  1997-09-18 14:35:00  1997-09-18    14:35:00  1997  ...
# 1  1997-07-25 13:00:00  1997-07-25    13:00:00  1997  ...
# 2  1997-07-20 13:55:00  1997-07-20    13:55:00  1997  ...
# 3  1997-07-24 13:30:00  1997-07-24    13:30:00  1997  ...
# 4  1997-08-31 08:00:00  1997-08-31     8:00:00  1997  ...
#
#    Average of PRED_Num/m3  stocked_category PRED_category CAL_category  \
# 0                8.010978              High          High      Average
# 1                0.364413           Average           Low          Low
# 2                0.364413           Average           Low          Low
# 3                0.364413           Average           Low          Low
# 4                0.364413           Average           Low          Low
#
#    CALIM_category  CALIM_category2  CYC_category  CYCIM_category  \
# 0            High             High          High            High
# 1             Low              Low           Low             Low
# 2             Low              Low           Low             Low
# 3             Low              Low           Low             Low
# 4             Low              Low           Low             Low
#
#    DAP_category  NDAP_category
# 0          High        Average
# 1           Low            Low
# 2           Low            Low
# 3           Low            Low
# 4           Low            Low
#
# [5 rows x 33 columns]

# %%
#dropping unnamed column
df_anglers = df_anglers.drop('Unnamed: 0', axis=1)

# %%
df_anglers.head()
# Out:
#          category         species      waterbody lake     merge  \
# 0  Catch and Keep  chinook salmon     Lake Huron   HU  lk_huron
# 1  Catch and Keep      lake trout  Lake Superior   SU    lk_sup
# 2  Catch and Keep      lake trout  Lake Superior   SU    lk_sup
# 3  Catch and Keep      lake trout  Lake Superior   SU    lk_sup
# 4  Catch and Keep      lake trout  Lake Superior   SU    lk_sup
#
#               datetime date caught time caught  year  weight lbs  ...  \
# 0  1997-09-18 14:35:00  1997-09-18    14:35:00  1997       28.75  ...
# 1  1997-07-25 13:00:00  1997-07-25    13:00:00  1997       38.38  ...
# 2  1997-07-20 13:55:00  1997-07-20    13:55:00  1997       29.50  ...
# 3  1997-07-24 13:30:00  1997-07-24    13:30:00  1997       25.50  ...
# 4  1997-08-31 08:00:00  1997-08-31     8:00:00  1997       22.81  ...
#
#    Average of PRED_Num/m3 stocked_category PRED_category  CAL_category  \
# 0                8.010978             High          High       Average
# 1                0.364413          Average           Low           Low
# 2                0.364413          Average           Low           Low
# 3                0.364413          Average           Low           Low
# 4                0.364413          Average           Low           Low
#
#    CALIM_category  CALIM_category2  CYC_category  CYCIM_category  \
# 0            High             High          High            High
# 1             Low              Low           Low             Low
# 2             Low              Low           Low             Low
# 3             Low              Low           Low             Low
# 4             Low              Low           Low             Low
#
#    DAP_category  NDAP_category
# 0          High        Average
# 1           Low            Low
# 2           Low            Low
# 3           Low            Low
# 4           Low            Low
#
# [5 rows x 32 columns]

# %%
df_anglers.shape
# Out:
# (2747, 32)

# %% [markdown]
# #all appears to have imported as expected

# %% [markdown]
# # Creating cluster by elbow method

# %%
#having column names
df_anglers.columns
# Out:
# Index(['category', 'species', 'waterbody', 'lake', 'merge', 'datetime',
#        'date caught', 'time caught', 'year', 'weight lbs', 'length in',
#        'method', 'bait', 'time hour caught', 'state minimum length in',
#        'number_stocked', 'Average of CAL_Num/m3', 'Average of CALIM_Num/m3',
#        'Average of CYC_Num/m3', 'Average of CYCIM_Num/m3',
#        'Average of DAP_Num/m3', 'Average of NDAP_Num/m3',
#        'Average of PRED_Num/m3', 'stocked_category', 'PRED_category',
#        'CAL_category', 'CALIM_category', 'CALIM_category2', 'CYC_category',
#        'CYCIM_category', 'DAP_category', 'NDAP_category'],
#       dtype='object')

# %%
#creating a dataframe with just the variables that can be analyzed
df_numbers = df_anglers[['time hour caught','number_stocked','length in','weight lbs','number_stocked', 'Average of CAL_Num/m3', 'Average of CALIM_Num/m3',
       'Average of CYC_Num/m3', 'Average of CYCIM_Num/m3','Average of DAP_Num/m3', 'Average of NDAP_Num/m3', 'Average of PRED_Num/m3']]

# %%
num_cl = range(1, 10) # Defines the range of potential clusters in the data.
kmeans = [KMeans(n_clusters=i) for i in num_cl] # Defines k-means clusters in the range assigned above.

# %%
score = [kmeans[i].fit(df_numbers).score(df_numbers) for i in range(len(kmeans))] # Creates a score that represents 
# a rate of variation for the given cluster option.

score
# Out:
# [-1.796711399171239e+16,
#  -3455689647446916.5,
#  -805831697897912.5,
#  -526834101627507.5,
#  -306037669481215.25,
#  -137622878316034.03,
#  -98442419558843.64,
#  -58801912807426.234,
#  -43871874104520.8]

# %%
# Plot the elbow curve using PyLab.

pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

# %% [markdown]
# #the curve takes a jump from 2 to 3, so 3 clusters is optimal

# %% [markdown]
# # Begin the k-means clustering

# %%
# Create the k-means object.

kmeans = KMeans(n_clusters = 3)

# %%
# Fit the k-means object to the data.

kmeans.fit(df_numbers)
# Out:
# KMeans(n_clusters=3)

# %%
# let's see the number of clusters
df_numbers['clusters'] = kmeans.fit_predict(df_numbers)
# Out:
# C:\Users\Selena\AppData\Local\Temp\ipykernel_11588\2988037419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_numbers['clusters'] = kmeans.fit_predict(df_numbers)

# %%
df_numbers.head()
# Out:
#    time hour caught  number_stocked  length in  weight lbs  number_stocked  \
# 0                14       6672382.0       40.0       28.75       6672382.0
# 1                13       3760410.0       43.0       38.38       3760410.0
# 2                13       3760410.0       41.0       29.50       3760410.0
# 3                13       3760410.0       42.0       25.50       3760410.0
# 4                 8       3760410.0       42.0       22.81       3760410.0
#
#    Average of CAL_Num/m3  Average of CALIM_Num/m3  Average of CYC_Num/m3  \
# 0             1361.95200                4339.3447             612.466600
# 1              416.11438                1320.7786             112.298706
# 2              416.11438                1320.7786             112.298706
# 3              416.11438                1320.7786             112.298706
# 4              416.11438                1320.7786             112.298706
#
#    Average of CYCIM_Num/m3  Average of DAP_Num/m3  Average of NDAP_Num/m3  \
# 0               2576.43920            2191.528800               843.75570
# 1                558.61096              41.561607                53.41791
# 2                558.61096              41.561607                53.41791
# 3                558.61096              41.561607                53.41791
# 4                558.61096              41.561607                53.41791
#
#    Average of PRED_Num/m3  clusters
# 0                8.010978         1
# 1                0.364413         2
# 2                0.364413         2
# 3                0.364413         2
# 4                0.364413         2

# %%
#seeing the number of value counts
df_numbers['clusters'].value_counts()
# Out:
# 0    1231
# 1     818
# 2     698
# Name: clusters, dtype: int64

# %%
# setting the colors to the clusters
df_numbers.loc[df_numbers['clusters'] == 2, 'cluster'] = 'green'
df_numbers.loc[df_numbers['clusters'] == 1, 'cluster'] = 'purple'
df_numbers.loc[df_numbers['clusters'] == 0, 'cluster'] = 'pink'
# Out:
# C:\Users\Selena\AppData\Local\Temp\ipykernel_11588\505345784.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_numbers.loc[df_numbers['clusters'] == 2, 'cluster'] = 'green'

# %%
# Plot the clusters for the "Length" and "Weight" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['weight lbs'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Weight in pounds') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %% [markdown]
# #a lot of overlapping here

# %%
# Plot the clusters for the "Length" and "Time Caught" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['time hour caught'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Time Caught') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %% [markdown]
# #longer fish are not caught at a specific time. These are all species of fish though

# %%
# Plot the clusters for the "Length" and "Average of CAL_Num/m3" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['Average of CAL_Num/m3'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('CAL') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %% [markdown]
# #this clustering isn't helpful either

# %%
# Plot the clusters for the "Length" and "Average of CALIM_Num/m3" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['Average of CALIM_Num/m3'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('CALIM') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %%
# Plot the clusters for the "Length" and "Average of CYC_Num/m3" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['Average of CYC_Num/m3'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('CYC') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %% [markdown]
# #no helpful pattern here.

# %%
# Plot the clusters for the "Length" and "Average of CYCIM_Num/m3" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['Average of CYCIM_Num/m3'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('CYCIM') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %% [markdown]
# #for some reason the clustering isn't nice and clean. This isn't helpful either

# %%
# Plot the clusters for the "Length" and "Average of DAP_Num/m3" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['Average of DAP_Num/m3'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('DAP') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %% [markdown]
# #no helpful info here either

# %%
# Plot the clusters for the "Length" and "Average of NDAP_Num/m3" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['Average of NDAP_Num/m3'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('NDAP') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %% [markdown]
# #Nothing helpful here either

# %%
# Plot the clusters for the "Length" and "Average of PRED_Num/m3" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_numbers['Average of PRED_Num/m3'], y=df_numbers['length in'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('PRED') # Label x-axis.
plt.ylabel('Length in inches') # Label y-axis.
plt.show()

# %% [markdown]
# #nothing helpful
